# %%
import models as m
from tools import tools as t

# %%
a = m.Model_1d(plane = False)
x, y_the = a.theoretical_equation()
y = t.normalize(y_the)
t.plot_1d(x, y)

# %%
a = m.Model_1d()
x1, y_the = a.theoretical_equation()
y1 = t.normalize(y_the)
t.plot_1d(x1, y1)

# %%
x, y_hel = a.helmholtz_equation()
y = t.normalize(y_hel)
t.plot_1d(x, y, x1, y1)

# %%
print(t.integral_krit(y, y1))
# Out:
# 0.9225569519527986
